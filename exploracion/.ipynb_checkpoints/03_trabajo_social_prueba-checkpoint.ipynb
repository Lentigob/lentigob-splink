# %% [markdown]
# # Exploración SPlink con datos de trabajo social de COVID-19

# %% [markdown]
# Esta es una exploración de la biblioteca Splink siguiendo el [tutorial](https://moj-analytical-services.github.io/splink/demos/tutorials/00_Tutorial_Introduction.html) que provee la documentación y usando la base de datos:
#
# INER_COVID19_TrabajoSocial.csv

# %%
# Llamado de dependencias y carga de datos
import os
import pandas as pd
import unicodedata
import re

ruta_datos = os.path.join("data", "INER_COVID19_TrabajoSocial.csv")
df = pd.read_csv(ruta_datos, encoding="utf-8")

# %%
df.head(5)
# Out:
#    AÑO  FILA  EXPEDIENTE NO. HISTORIA FECHA DE ELABORACIÓN APELLIDO PATERNO  \
# 0    0     0      236215    IAN600536  2020-01-01 10:51:00           CORONA
# 1    0     1      236216    IAN600533  2020-01-01 07:05:00         ZAMBRANO
# 2    0     2      236217    IAN561983  2020-01-01 11:50:00          VAZQUEZ
# 3    0     3      236220    IAN486680  2020-01-01 17:02:00           VARGAS
# 4    0     4      236221    IAN600607  2020-01-02 00:00:00       HERNANDEZ
#
#   APELLIDO MATERNO         NOMBRE                       EDAD  \
# 0            LOPEZ  SHEILA YADIRA   45 años 2 meses 22 días
# 1            RIVAS      JOSE LUIS   70 años 3 meses 20 días
# 2           JUAREZ    ANNIE SOFIA    3 años 8 meses 11 días
# 3     DE  BASTERRA        RICARDO   55 años 4 meses 14 días
# 4           MEDINA       CATALINA  63 años 10 meses 15 días
#
#   FECHA DE NACIMIENTO     GENERO                               DIAGNOSTICO  \
# 0          1974-10-11   Femenino                           Estado asmático
# 1          1949-09-13  Masculino           Anormalidades de la respiración
# 2          2016-04-22   Femenino           Anormalidades de la respiración
# 3          1964-08-19  Masculino  Influenza debida a virus no identificado
# 4          1956-03-02   Femenino       Neumonía, organismo no especificado
#
#           ESCOLARIDAD    OCUPACIÓN DERECHOHABIENTE Y/O BENEFICIARIO  \
# 0      NMS INCOMPLETO        Hogar                         SEG.POP.
# 1  PRIMARIA COMPLETA   DESEMPLEADO                          NINGUNO
# 2         PREPRIMARIA        MENOR                         SEG.POP.
# 3  POSTGRADO COMPLETO     PROFESOR                          NINGUNO
# 4  PRIMARIA COMPLETA         Hogar                          NINGUNO
#
#   DELEGACIÓN O MUNICIPIO PERMANENTE ESTADO / PAIS PERMANENTE TOTAL DE PUNTOS  \
# 0               Tlalnepantla de Baz            México,Mexico              27
# 1                        Iztapalapa  Ciudad de México,Mexico              24
# 2                        Iztapalapa  Ciudad de México,Mexico              25
# 3                          Coyoacán  Ciudad de México,Mexico              81
# 4               Ecatepec de Morelos            México,Mexico              12
#
#   NIVEL SOCIOECONÓMICO Unnamed: 19
# 0                    2         NaN
# 1                    1         NaN
# 2                    2         NaN
# 3                    5         NaN
# 4                   1X         NaN

# %%
len(df)
# Out:
# 14796

# %% [markdown]
# ## Preliminares

# %% [markdown]
# Splink requiere bases de datos lo más limpias posibles. En este caso se añade un identificador único consecutivo (`unique_id`) a la tabla, además de que se limpian espacios extras en blanco al inicio, fin y entre cada nombre completo de la columna `nombre`.

# %%
# Añadiendo un ID
df["unique_id"] = range(1, len(df) + 1)
df.insert(0, "unique_id", df.pop("unique_id"))

# %%
# Limpiando espacios en la columna nombre
df["NOMBRE"] = df["NOMBRE"].str.replace(r"\s+", " ", regex=True).str.strip()

# %%
# Limpiar nombres de columnas
def limpiar_columnas(df):
    def limpiar_nombre(col):
        # Quitar acentos
        col = unicodedata.normalize('NFKD', col).encode('ascii', 'ignore').decode('utf-8')
        # Sustituir espacios (y cualquier whitespace) por guiones bajos
        col = re.sub(r'\s+', '_', col.strip())
        # Mayúsculas
        return col.upper()
    
    df.columns = [limpiar_nombre(str(col)) for col in df.columns]
    return df

# %%
df = limpiar_columnas(df)

# %% [markdown]
# ## 2. Análisis Exploratorio de Datos usando Splink

# %% [markdown]
# Splink provee de herramientas para el análisis exploratorio de datos que facilitarán la elección de reglas de bloqueo en los siguientes pasos. Exploro aquí las que se usan en el tutorial de la biblioteca.

# %% [markdown]
# ### Datos faltantes

# %%
from splink.exploratory import completeness_chart
from splink import DuckDBAPI
db_api = DuckDBAPI()
completeness_chart(df, db_api=db_api)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Distribución de los valores en los datos

# %%
from splink.exploratory import profile_columns

profile_columns(df, db_api=DuckDBAPI(), top_n=10, bottom_n=5)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ## 3. Escoger las reglas de bloqueo

# %% [markdown]
# Se usan las reglas de bloqueo para generar pares de registros candidatos a comparar. Según la [documentación el objetivo de éstas es doble](https://moj-analytical-services.github.io/splink/demos/tutorials/03_Blocking.html#devising-effective-blocking-rules-for-prediction):
#
# 1. Eliminar suficientes pares de comparación que no coincidan para que el proceso de vinculación de registros sea lo suficientemente pequeño para que pueda calcularse.
#
# 2. Eliminar la menor cantidad posible de pares que coincidan realmente (idealmente ninguno).
#
# Splink recomienda la generación de múltiples reglas de bloqueo para lograr ambos objetivos, por lo cual podrían ser entre 3 y 10 reglas de bloqueo.
#
# A diferencia de los datasets de costos y de comorbilidad, este incluye los apellidos y el nombre de los pacientes separados, además de que tenemos datos de género y localidad, entonces escogeremos como candidatos a reglas de bloqueo las siguientes columnas.

# %% [markdown]
# 1. `APELLIDO_PATERNO` y `NOMBRE`
# 2. `APELLIDO_PATERNO` y `NOMBRE` usando una regla de distancia de Levenshtein

# %%
# Candidatos a reglas de bloqueo
from splink import block_on
block_on("APELLIDO_PATERNO", "NOMBRE")
block_on("substr(NOMBRE, 1,1)", "APELLIDO_PATERNO")

# %% [markdown]
# Para saber si los candidatos a las reglas de bloqueo funcionarán, Splink tiene diveras herramientas para ayudar a elegir.

# %% [markdown]
# ### Contar el número de comparaciones creadas por una sóla regla de bloqueo
#
# El número de comparaciones que genera una regla de bloqueo crece de forma cuadrática respecto al número de registros. El número de pares en una [link text](https://)tabla con N registros está dado por N(N-1)/2

# %%
from splink.blocking_analysis import count_comparisons_from_blocking_rule

db_api = DuckDBAPI()

br_nombre = block_on("APELLIDO_PATERNO", "NOMBRE")

counts = count_comparisons_from_blocking_rule(
    table_or_tables=df,
    blocking_rule=br_nombre,
    link_type="dedupe_only",
    db_api=db_api,
)

counts
# Out:
# {'number_of_comparisons_generated_pre_filter_conditions': 16600,
#  'number_of_comparisons_to_be_scored_post_filter_conditions': 912,
#  'filter_conditions_identified': '',
#  'equi_join_conditions_identified': 'l."APELLIDO_PATERNO" = r."APELLIDO_PATERNO" AND l."NOMBRE" = r."NOMBRE"',
#  'link_type_join_condition': 'where l."unique_id" < r."unique_id"'}

# %%
br_nombre_lev = block_on("substr(NOMBRE, 1,1)", "APELLIDO_PATERNO")

counts = count_comparisons_from_blocking_rule(
    table_or_tables=df,
    blocking_rule=br_nombre_lev,
    link_type="dedupe_only",
    db_api=db_api,
)

counts
# Out:
# {'number_of_comparisons_generated_pre_filter_conditions': 125418,
#  'number_of_comparisons_to_be_scored_post_filter_conditions': 55321,
#  'filter_conditions_identified': '',
#  'equi_join_conditions_identified': 'SUBSTRING(l.NOMBRE, 1, 1) = SUBSTRING(r.NOMBRE, 1, 1) AND l."APELLIDO_PATERNO" = r."APELLIDO_PATERNO"',
#  'link_type_join_condition': 'where l."unique_id" < r."unique_id"'}

# %% [markdown]
# ### _Worst offending values_

# %%
from splink.blocking_analysis import n_largest_blocks

result = n_largest_blocks(    table_or_tables=df,
    blocking_rule= block_on("DELEGACION_O_MUNICIPIO_PERMANENTE", "APELLIDO_PATERNO"),
    link_type="dedupe_only",
    db_api=db_api,
    n_largest=10
    )

result.as_pandas_dataframe()
# Out:
#         key_0      key_1  count_l  count_r  block_count
# 0     TLALPAN  HERNANDEZ       42       42         1764
# 1  Iztapalapa  HERNANDEZ       35       35         1225
# 2     Tlalpan  HERNANDEZ       30       30          900
# 3  Iztapalapa     GARCIA       26       26          676
# 4  IZTAPALAPA  HERNANDEZ       26       26          676
# 5  IZTAPALAPA      LOPEZ       22       22          484
# 6     TLALPAN     GARCIA       20       20          400
# 7  IZTAPALAPA   GONZALEZ       20       20          400
# 8  IZTAPALAPA     GARCIA       20       20          400
# 9     Tlalpan     GARCIA       20       20          400

# %% [markdown]
# ### Contar el número de comparaciones creadas por una lista de reglas de agrupamiento
#
# Genera una gráfica de comparaciones acumuladas donde cada barra representa cuántas comparaciones nuevas y únicas aporta cada regla adicional, después de desduplicar contra las reglas anteriores.
#
# - Si una regla aporta muy pocas comparaciones nuevas y únicas significa que casi todos los pares de registros nuevos que genera ya estaban cubiertos por alguna regla o reglas anteriores, es decir, es redundante.
# - Si una regla aporta muchas más comparaciones nuevas y únicas significa que está capturando pares que las otras reglas no cubren, por lo tanto, es valiiosa.
# - El acumulado final me indica si la lista de reglas es manejable computacionalmente.

# %%
from splink.blocking_analysis import (
    cumulative_comparisons_to_be_scored_from_blocking_rules_chart,
)

blocking_rules_for_analysis = [
    block_on("substr(APELLIDO_PATERNO, 1,1)", "NOMBRE"),
    block_on("FECHA_DE_NACIMIENTO"),
    block_on("DELEGACION_O_MUNICIPIO_PERMANENTE", "NOMBRE"),
    "l.NOMBRE = r.NOMBRE and levenshtein(l.APELLIDO_PATERNO, r.APELLIDO_PATERNO) < 2"
]


cumulative_comparisons_to_be_scored_from_blocking_rules_chart(
    table_or_tables=df,
    blocking_rules=blocking_rules_for_analysis,
    db_api=db_api,
    link_type="dedupe_only",
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Esta gráfica nos dice que la elección de mis reglas de bloqueo es correcta, se generan un número considerable de comparaciones nuevas con la lista de reglas de bloqueo elegidas.

# %% [markdown]
# ## 4. Estimar los parámetros del modelo

# %% [markdown]
# ### Comparaciones (`Comparison`)
#
# Una Comparación o *Comparison* representa como se va a evaluar la similitud de un campo. El modelo que se construye usando Splink consta de muchas comparaciones.
#
# Las comparaciones tienen niveles `ComparisonLevels` donde se asignan calificaciones de similitud entre las columnas para cierta comparación. Por ejemplo:

# %% [markdown]
# ```
# Modelo de vinculación de datos
# ├─-- Comparison: fechaing
# │    ├─-- ComparisonLevel: Coincidencia exacta
# │    ├─-- ComparisonLevel: Un caracter de diferencia
# │    ├─-- ComparisonLevel: Cualquier otra
# ├─-- Comparison: nombre
# │    ├─-- ComparisonLevel: Coincidencia exacta
# │    ├─-- ComparisonLevel: JaroWinkler > 0.9
# │    ├─-- ComparisonLevel: Cualquier otra
# │    etc.
# ```

# %% [markdown]
# Para `fechaing` o pienso que en particular para cualquier fecha
# | fechaing_l      | fechaegr_r      | comparison_level        | interpretation |
# |------------|------------|--------------------------|-----------------|
# | 1971-05-24 | 1971-05-24 | Coincidencia exacta            | great match     |
# | 1971-05-24 | 1971-06-24 | Un caracter de diferencia | fuzzy match     |
# | 1971-05-24 | 2000-01-02 | Cualquier otra                | bad match       |

# %% [markdown]
# Para `nombre`
#
# | nombre_l | nombre_r | comparison_level | interpretation                                    |
# |-----------|-----------|-------------------|----------------------------------------------------|
# | VICENTE MARTIN VALENCIA CHAVEZ       | VICENTE MARTIN VALENCIA CHAVEZ       | Exact match       | great match |
# | MARTIN VALENCIA CHAVEZ       | VICENTE MARTIN VALENCIA CHAVEZ    | All JaroWinkler >0.9         | great match?
# | VICENTE MARTIN VLENCIA CHAVEZ       | JOSE PEDRO VALENCIA CHAVEZ    | other         | bad match, this comparison has no notion of nicknames

# %% [markdown]
# En el segundo caso de nombre donde difiere por el segundo nombre el registro, no es tan conveniente usar `JaroWinkler`, ya que este método le da peso al inicio del string y al faltar el primer nombre de Vicente, la comparación ya no es tan ideal. Para ello Splink tiene un módulo de comparaciones "out of the box" que incluyen estos casos, así como también se pueden customizar las reglas para hacer comparaciones.

# %% [markdown]
# ### Especificar el modelo usando las comparaciones

# %% [markdown]
# Categoría 1: Funciones genéricas que aplican una función de fuzzy matching en particular. Por ejemplo, distancia de Levenshtein.

# %%
import splink.comparison_library as cl

nombre_comparacion = cl.LevenshteinAtThresholds("nombre", 2)
print(nombre_comparacion.get_comparison("duckdb").human_readable_description)
# Out:
# Comparison 'LevenshteinAtThresholds' of "nombre".
# Similarity is assessed using the following ComparisonLevels:
#     - 'nombre is NULL' with SQL rule: "nombre_l" IS NULL OR "nombre_r" IS NULL
#     - 'Exact match on nombre' with SQL rule: "nombre_l" = "nombre_r"
#     - 'Levenshtein distance of nombre <= 2' with SQL rule: levenshtein("nombre_l", "nombre_r") <= 2
#     - 'All other comparisons' with SQL rule: ELSE

# %% [markdown]
# Categoría 2: Funciones de comparación diseñadas para tipos de datos específicos.

# %%
nombre_completo_comparacion = cl.NameComparison("nombre")
print(nombre_completo_comparacion.get_comparison("duckdb").human_readable_description)
# Out:
# Comparison 'NameComparison' of "nombre".
# Similarity is assessed using the following ComparisonLevels:
#     - 'nombre is NULL' with SQL rule: "nombre_l" IS NULL OR "nombre_r" IS NULL
#     - 'Exact match on nombre' with SQL rule: "nombre_l" = "nombre_r"
#     - 'Jaro-Winkler distance of nombre >= 0.92' with SQL rule: jaro_winkler_similarity("nombre_l", "nombre_r") >= 0.92
#     - 'Jaro-Winkler distance of nombre >= 0.88' with SQL rule: jaro_winkler_similarity("nombre_l", "nombre_r") >= 0.88
#     - 'Jaro-Winkler distance of nombre >= 0.7' with SQL rule: jaro_winkler_similarity("nombre_l", "nombre_r") >= 0.7
#     - 'All other comparisons' with SQL rule: ELSE

# %% [markdown]
# ### Especificar el diccionario de configuraciones

# %%
# Antes para poder comparar las fechas de ingreso y egreso voy a customizar un poco la función DateOfBirthComparison

fecha_ingreso_comparacion = cl.DateOfBirthComparison(
    "fechaing",
    input_is_string=True,
    datetime_format="%Y-%m-%d",
    invalid_dates_as_null=True,
    datetime_thresholds=[1, 7, 365],       # límites en días
    datetime_metrics=["day", "day", "day"] # unidad de cada threshold
)

fecha_egreso_comparacion = cl.DateOfBirthComparison(
    "fechaegr",
    input_is_string=True,
    datetime_format="%Y-%m-%d",
    invalid_dates_as_null=True,
    datetime_thresholds=[1, 7, 365],       # límites en días
    datetime_metrics=["day", "day", "day"] # unidad de cada threshold
)

# %%
from splink import Linker, SettingsCreator, block_on, DuckDBAPI

settings = SettingsCreator(
    link_type="dedupe_only",
    comparisons=[
        cl.NameComparison("nombre"),
        fecha_ingreso_comparacion,
        fecha_egreso_comparacion
    ],
    blocking_rules_to_generate_predictions=[
        block_on("nombre", "fechaing"),
        block_on("nombre", "fechaegr"),
    ],
    retain_intermediate_calculation_columns=True,
)

linker = Linker(df, settings, db_api=DuckDBAPI())

# %% [markdown]
# ### Estimar los parámetros del modelo

# %% [markdown]
# a. El parámetro `probability_two_random_records_match` es la probabilidad de que dos registros tomados al azar de tus datos de entrada representen un match (típicamente un número muy pequeño).
#
# b. Los valores `u` son la proporción de registros que caen en cada `ComparisonLevel` entre los registros que verdaderamente no son coincidencia.
#
# c. Los valores `m` son la proporción de registros que caen en cada `ComparisonLevel` entre los registros que verdaderamente sí son coincidencia.

# %%
# a. probability_two_random_records_matchdf_predictions

deterministic_rules = [
    block_on("nombre", "expediente")
]

linker.training.estimate_probability_two_random_records_match(deterministic_rules, recall=0.7)
# Out:
# INFO:splink.internals.linker_components.training:Probability two random records match is estimated to be  2.98e-05.
# This means that amongst all possible pairwise record comparisons, one in 33,528.55 are expected to match.  With 9,148,503 total possible comparisons, we expect a total of around 272.86 matching pairs

# %%
# b.
linker.training.estimate_u_using_random_sampling(max_pairs=1e6)
# Out:
# WARNING:splink.internals.linker_components.training:You are using the default value for `max_pairs`, which may be too small and thus lead to inaccurate estimates for your model's u-parameters. Consider increasing to 1e8 or 1e9, which will result in more accurate estimates, but with a longer run time.
# INFO:splink.internals.estimate_u:----- Estimating u probabilities using random sampling -----
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# INFO:splink.internals.estimate_u:
# Estimated u probabilities using random sampling
# INFO:splink.internals.settings:
# Your model is not yet fully trained. Missing estimates for:
#     - nombre (no m values are trained).
#     - fechaing (no m values are trained).
#     - fechaegr (no m values are trained).

# %%
# c.
linker.training.estimate_m_from_label_column("expediente")
# Out:
# INFO:splink.internals.m_training:------ Estimating m probabilities using from column expediente -------
# INFO:splink.internals.m_u_records_to_parameters:m probability not trained for fechaing - Abs date difference <= 1 day (comparison vector value: 3). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.m_u_records_to_parameters:m probability not trained for fechaegr - Exact match on date of birth (comparison vector value: 5). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.m_u_records_to_parameters:m probability not trained for fechaegr - Abs date difference <= 1 day (comparison vector value: 3). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.settings:
# Your model is not yet fully trained. Missing estimates for:
#     - fechaing (some m values are not trained).
#     - fechaegr (some m values are not trained).

# %%
#c.
sesion_2 = block_on("nombre")
linker.training.estimate_parameters_using_expectation_maximisation(sesion_2)
# Out:
# INFO:splink.internals.em_training_session:
# ----- Starting EM training session -----
#
# INFO:splink.internals.em_training_session:Estimating the m probabilities of the model by blocking on:
# l."nombre" = r."nombre"
#
# Parameter estimates will be made for the following comparison(s):
#     - fechaing
#     - fechaegr
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - nombre
# INFO:splink.internals.expectation_maximisation:
# WARNING:splink.internals.expectation_maximisation:WARNING:
# Level Abs date difference <= 1 day on comparison fechaing not observed in dataset, unable to train m value
#
# WARNING:splink.internals.expectation_maximisation:WARNING:
# Level Exact match on date of birth on comparison fechaegr not observed in dataset, unable to train m value
#
# WARNING:splink.internals.expectation_maximisation:WARNING:
# Level Abs date difference <= 1 day on comparison fechaegr not observed in dataset, unable to train m value
#
# INFO:splink.internals.expectation_maximisation:Iteration 1: Largest change in params was -0.95 in the m_probability of fechaegr, level `Exact match on date of birth`
# INFO:splink.internals.expectation_maximisation:Iteration 2: Largest change in params was 0.0931 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:Iteration 3: Largest change in params was 0.0602 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:Iteration 4: Largest change in params was 0.035 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:Iteration 5: Largest change in params was 0.0189 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:Iteration 6: Largest change in params was 0.00987 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:Iteration 7: Largest change in params was 0.00504 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:Iteration 8: Largest change in params was 0.00255 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:Iteration 9: Largest change in params was 0.00128 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:Iteration 10: Largest change in params was 0.000644 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:Iteration 11: Largest change in params was 0.000323 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:Iteration 12: Largest change in params was 0.000162 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:Iteration 13: Largest change in params was 8.1e-05 in probability_two_random_records_match
# INFO:splink.internals.expectation_maximisation:
# EM converged after 13 iterations
# INFO:splink.internals.em_training_session:m probability not trained for fechaing - Abs date difference <= 1 day (comparison vector value: 3). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.em_training_session:m probability not trained for fechaegr - Exact match on date of birth (comparison vector value: 5). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.em_training_session:m probability not trained for fechaegr - Abs date difference <= 1 day (comparison vector value: 3). This usually means the comparison level was never observed in the training data.
# INFO:splink.internals.settings:
# Your model is not yet fully trained. Missing estimates for:
#     - fechaing (some m values are not trained).
#     - fechaegr (some m values are not trained).
# <EMTrainingSession, blocking on l."nombre" = r."nombre", deactivating comparisons nombre>

# %% [markdown]
# ### Visualizando los pesos

# %%
linker.visualisations.match_weights_chart()
# Out:
# alt.VConcatChart(...)

# %%
linker.visualisations.m_u_parameters_chart()
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## 5. Predicción

# %%
df_predictions = linker.inference.predict(threshold_match_probability=0.2)
df_predictions.as_pandas_dataframe(limit=25)
# Out:
# INFO:splink.internals.linker_components.inference:Blocking time: 0.01 seconds
# INFO:splink.internals.linker_components.inference:Predict time: 0.21 seconds
# WARNING:splink.internals.linker:
#  -- WARNING --
# You have called predict(), but there are some parameter estimates which have neither been estimated or specified in your settings dictionary.  To produce predictions the following untrained trained parameters will use default values.
# Comparison: 'fechaing':
#     m values not fully trained
# Comparison: 'fechaegr':
#     m values not fully trained
#    match_weight  match_probability  unique_id_l  unique_id_r  \
# 0      0.848488           0.642935         1544         1888
# 1      0.848488           0.642935         2069         2181
# 2      0.848488           0.642935         1938         2202
# 3      0.848488           0.642935         2324         2570
# 4      1.187825           0.694944         4114         4116
#
#                          nombre_l                        nombre_r  \
# 0             CARLOS PONCE CHAVEZ             CARLOS PONCE CHAVEZ
# 1        JUAN VICTOR NU?EZ JUAREZ        JUAN VICTOR NU?EZ JUAREZ
# 2       ALFREDO SARABIA CABALLERO       ALFREDO SARABIA CABALLERO
# 3         JOSE HUGO PEREZ SALINAS         JOSE HUGO PEREZ SALINAS
# 4  VICENTE MARTIN VALENCIA CHAVEZ  VICENTE MARTIN VALENCIA CHAVEZ
#
#    gamma_nombre  tf_nombre_l  tf_nombre_r     bf_nombre  bf_tf_adj_nombre  \
# 0             4     0.000468     0.000468  37088.727273          0.052705
# 1             4     0.000468     0.000468  37088.727273          0.052705
# 2             4     0.000468     0.000468  37088.727273          0.052705
# 3             4     0.000468     0.000468  37088.727273          0.052705
# 4             4     0.001169     0.001169  37088.727273          0.021082
#
#    fechaing_l  fechaing_r  gamma_fechaing  bf_fechaing  fechaegr_l  \
# 0  2020-12-30  2020-12-30               5    23.103623  2021-01-05
# 1  2021-03-14  2021-03-14               5    23.103623  2021-03-17
# 2  2021-03-01  2021-03-01               5    23.103623  2021-03-01
# 3  2021-04-12  2021-04-12               5    23.103623  2021-04-22
# 4  2023-03-04  2023-03-04               5    23.103623  2023-03-04
#
#    fechaegr_r  gamma_fechaegr  bf_fechaegr match_key
# 0  2021-02-23               1     1.336731         0
# 1  2021-04-01               1     1.336731         0
# 2  2021-04-03               1     1.336731         0
# 3  2021-06-12               1     1.336731         0
# 4  2023-03-06               4     4.227998         0
